# %%
import pandas as pd
import csv
csv_data = pd.read_csv('Information is Beautiful- Data Breaches (public) - 2017 update.csv')
csv_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
csv_data.drop(csv_data.columns[[0]], axis=1)
# Out:
#                                             Unnamed: 1  \
# 0                                     alternative name
# 1                                                  NaN
# 2                                      American Online
# 3             Business outsourcing, payrolls, benefits
# 4    Computer backup tape containing personal infor...
# 5                                                  NaN
# 6    Third-party payment processor for Visa, Master...
# 7                                                  NaN
# 8                                    Mortgage financer
# 9                 Japanese telecommunications operator
# 10                                                 NaN
# 11                                     American Online
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# ...

# %%
csv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 18 columns):
# Unnamed: 0     254 non-null object
# Unnamed: 1     119 non-null object
# Unnamed: 2     219 non-null object
# Unnamed: 3     255 non-null object
# Unnamed: 4     253 non-null object
# Unnamed: 5     254 non-null object
# Unnamed: 6     254 non-null object
# Unnamed: 7     63 non-null object
# Unnamed: 8     255 non-null object
# Unnamed: 9     255 non-null object
# Unnamed: 10    1 non-null object
# Unnamed: 11    1 non-null object
# Unnamed: 12    3 non-null object
# Unnamed: 13    1 non-null object
# Unnamed: 14    254 non-null object
# Unnamed: 15    54 non-null object
# Unnamed: 16    5 non-null object
# Unnamed: 17    103 non-null object
# dtypes: object(18)
# memory usage: 35.9+ KB

# %%
csv_data.head()
# Out:
#                   Unnamed: 0  \
# 0                     Entity
# 1                        NaN
# 2                        AOL
# 3  Automatic Data Processing
# 4            Ameritrade Inc.
#
#                                           Unnamed: 1  \
# 0                                   alternative name
# 1                                                NaN
# 2                                    American Online
# 3           Business outsourcing, payrolls, benefits
# 4  Computer backup tape containing personal infor...
#
#                                           Unnamed: 2  \
# 0                                              story
# 1  Elaboration if there's an interesting story or...
# 2  A former America Online software engineer stol...
# 3                                                NaN
# 4                                      online broker
#
#                                           Unnamed: 3  \
# 0                                               YEAR
# ...

# %%
csv_data.describe
# Out:
# <bound method NDFrame.describe of                                          Unnamed: 0  \
# 0                                            Entity
# 1                                               NaN
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# ...

# %%
csv_data2 = csv_data.copy()

# %%
csv_data2 = csv_data2.dropna(axis="columns", how="any")

# %%
csv_data2
# Out:
#                                             Unnamed: 3  \
# 0                                                 YEAR
# 1    years are encoded (0=2004, 8 = 2012, 9 = 2013,...
# 2                                                    0
# 3                                                    1
# 4                                                    1
# 5                                                    1
# 6                                                    1
# 7                                                    2
# 8                                                    2
# 9                                                    2
# 10                                                   2
# 11                                                   2
# 12                                                   2
# 13                                                   3
# 14                                                   3
# 15                                                   3
# ...

# %%
csv_data2 = csv_data.copy()

# %%
csv_data2
# Out:
#                                          Unnamed: 0  \
# 0                                            Entity
# 1                                               NaN
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# ...

# %%
csv_data2=csv_data2.fillna("")
csv_data2
# Out:
#                                          Unnamed: 0  \
# 0                                            Entity
# 1
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# ...

# %%
csv_data2.columns = csv_data2.iloc[0]
csv_data2
# Out:
# 0                                            Entity  \
# 0                                            Entity
# 1
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# ...

# %%
csv_data2 = csv_data2.reindex(csv_data2.index.drop(0))
csv_data2
# Out:
# 0                                            Entity  \
# 1
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# 18                         Driving Standards Agency
# ...

# %%
csv_data2.columns=['Entity','Alternative Name','Story','Year','Records Lost','Organization','Method of Leak','Interesting Story','No of Records Stolen','Data Sensitivity','Blank1','Blank2','Blank3','Blank4','Source Link 1','Source Link 2','Source Link 3','Source Name']
csv_data2
# Out:
#                                              Entity  \
# 1
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# 18                         Driving Standards Agency
# ...

# %%
keep_columns = ['Entity','Alternative Name','Story','Year','Records Lost','Organization','Method of Leak','Interesting Story','No of Records Stolen','Data Sensitivity','Source Link 1','Source Link 2','Source Name']
csv_data4 = csv_data2[keep_columns]
csv_data4
# Out:
#                                              Entity  \
# 1
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# 18                         Driving Standards Agency
# ...

# %%
csv_data4 = csv_data4.reindex(csv_data4.index.drop(1))
csv_data4
# Out:
#                                              Entity  \
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# 18                         Driving Standards Agency
# ...

# %%
csv_data5 = csv_data4.copy()

# %%
csv_data6 = csv_data5.copy()

# %%
csv_data6.to_csv('Assignment1Rucha.csv', index=False)
