# %% [markdown]
# # SCU MSIS Dashboard for Employers

# %% [markdown]
# #### This dashboard is intended to showcase the comptencies of the university and prospective employees to the potential employers (Audience).
# #### The dashboard is also a redesign version of the Lab session 6 based on the same idea, but a different perspective.

# %% [markdown]
# ### 1. Components of previous version of this Dashboard
# ### 1.1. Course - Skill set Coverage:

# %%
from IPython.display import Image
Image("9-1.png")

# %% [markdown]
# #### Critique: This visualization was created in order for the employers to view the course coverage of the most in-demand Information Systems skill set that SCU incucates in the MSIS students. This also includes instructions on how to navigate to the skill sets and view the courses offered. The only change I would want to make in this would be to include the skill sets in the visualization where the employers can interact with it from Left to Right instead of the other way.

# %% [markdown]
# ### 1.2. SCU Alumni Employers

# %%
from IPython.display import Image
Image("9-2.png")

# %% [markdown]
# #### Critique: Knowing who has employed SCU MSIS Alumni would be of supplementary importance to the employers, unless they are one of the listed companies.  I felt that there was another factor of the SCU MSIS Students that was more important than this to share on the dashboard. There is certainly no need to share the number of employed alumni and rank the companies accordingly.

# %% [markdown]
# ### 1.3. Progress of MSIS Students in their careers

# %%
from IPython.display import Image
Image("9-3.png")

# %% [markdown]
# #### Critique: This visualization is not relevant for the recruiters to know. Also, the salary really depends on where the SCU student works and what he/she does to derive this conclusion.

# %% [markdown]
# ### 2. Redesigned Visualizations:

# %% [markdown]
# ### 2.1. University Rankings:

# %%
from IPython.display import Image
Image("LS9.png")

# %% [markdown]
# #### One of the most important criteria for an employer is the ranking of the university. The rankings ensure that the university is highly competitive for the various judgement parameters that are used by the ranking committees on a uniform scale.  The visualization above shows the ranking data by numbers. It is very insightful and easy for the employers to read through these numbers.

# %% [markdown]
# ### 2.2. Course - Skill Set Coverage:

# %%
from IPython.display import Image
Image("9-5.png")

# %% [markdown]
# #### As mentioned in the earlier Critique of the visualization, the skillset has been moved to the left side in order to follow the reading sequence and direction. It now becomes easier to navigate through the visualization.

# %% [markdown]
# ### 2.3. Student Acceptance Criteria:

# %%
from IPython.display import Image
Image("LS - 9.png")

# %% [markdown]
# #### It is important for an employer to know that the university sets high standards for acceptance. This provides an assurance for the employer that the set of prospective employees is highly qualified and competitive to suit their requirements. The visualization above shows the acceptance criteria data by numbers. It is very insightful and easy for the employers to read through these numbers.

# %% [markdown]
# ### 3. Conclusion:
# #### The redesigned dashboard helps the employers to view the most important competencies of MSIS Students at SCU.
# #### The visualizations are organized to follow a proper sequence/flow of the information and the aesthetics of readability, color and space considerations.
