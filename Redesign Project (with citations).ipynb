# %% [markdown]
# # Roger Federer - The G.O.A.T.?

# %% [markdown]
# ### 1. Introduction -
# #### In today’s world, tennis is one of the most famous individual games. There have been legends in this game who have set remarkable records.
# #### There is a lot of data which can help me prove who is the greatest tennis player of all time. Today, I will prove with the relevant and critical data I gathered that Roger Federer has become the greatest player of all time. One can argue that Roger Federer does not hold a good record in head-to-head games with current top 5 seeded players and hence he is not the G.O.A.T. But I would like to put forth the overall tennis career record and not just in head-to-head games because winning an important game like the finals and getting the ultimate championship title tells us much more about the player.

# %% [markdown]
# ### 2. Audience –
# #### There are two types of audience that would be interested to look at this analysis –
# #### 2.1.	The ones who believe Roger Federer is the G.O.A.T. and would like to reassure themselves with the evidence of data
# #### 2.2.	The ones who would argue that Roger Federer is not the G.O.A.T.

# %% [markdown]
# ### 3. Reference link for the dashboard -
# #### http://www.atpworldtour.com/en/performance-zone/win-loss-index

# %% [markdown]
# #### This visualization is a simple representation of three metrics in a tabular form. The table includes Rank, Country, Picture, Name of the player, 52-Week index, 52-Week titles and 52-Week Win/Loss details of 101 players listed in the ATP Rankings for Men’s singles. Although Roger Federer is ranked at No. 1 in the table, this visualization has the following drawbacks-
#
# #### 1.	The audience already knows who Roger Federer is and hence, there is no need to have his photograph in the table.
# #### 2.	Since the claim of this analysis is focused on Roger Federer as an individual player, the flags that indicate the countries are not required for the analysis.
# #### 3.	The 52-Week index is in a format that is not easy to understand. Having a simpler format of numbers would provide a clearer and quicker understanding of the metric.
# #### 4.	The Win-Loss numbers are listed for each player. A person must be detail-oriented enough to go through all the numbers and compare the players or analyze the data to his/her understanding.
# #### 5.	Since the table is intended to display the Performance of the players, the Win-Loss numbers add to the confusion and the ranks are changed.

# %% [markdown]
# ### 4. Intermediate Versions -
# #### 1. The first version is intended to display the 52 Week index to the audience against the number of wins of the players. In this visualization, Roger Federer has the highest Index but it is confusing to see Nadal and other players that have won more matches, plotted to the right side of Federer's record. The index is not a clear metric.
#
# #### 2. The second version is intended to display the Maximum number of Grand Slam titles won by each player. However, it is not clear that Roger Federer has won the maximum Grand slam titles with the visualization.

# %%
from IPython.display import Image
Image("Intermediate Data 1.png")

# %%
from IPython.display import Image
Image("Intermediate Data 2.png")

# %% [markdown]
# ### 5. Final Versions -
# #### 1. The first version is intended to display Federer's record of 92% wins against his rank. This shows that he is way ahead of his immediate competitors. This graph also helps visualize a trend of the win% of all players. It is easy for the audience to understand the metrics and visualize the data to conclude that Roger Federer has the best record for Wins.
# #### 2. The second version is intended to display the Maximum number of Grand Slam titles won by each player in a away that the distribution of all the titles is clear and arranged in an order to naturally reflect the greatness of Federer in Men's Singles Tennis.
# #### 3. The third version is intended to display the maximum number of weeks that Federer has held the number 1 position amongst the other Number 1 players in their careers.

# %%
from IPython.display import Image
Image("Final Version 1.png")

# %%
from IPython.display import Image
Image("Final Version 2.png")

# %%
from IPython.display import Image
Image("Final version 3.png")

# %% [markdown]
# ### 6. Conclusion -
#
# #### Based on the evidences above, it is clear that Federer's record speak for themselves and he is indeed the G.O.A.T.!

# %% [markdown]
# #### Citations : ATP World Tour and Wikipedia
