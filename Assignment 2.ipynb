# %% [markdown]
# #Objective : To refute the claim
# import pandas as pd
# import csv
# csv_data1 = pd.read_csv('CSV2017.csv') #import file
# csv_data1

# %%
csv_data2 = csv_data1.copy()
csv_data2.columns = csv_data2.iloc[0]
csv_data2
# Out:
# 0                                            Entity  \
# 0                                            Entity
# 1                                               NaN
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# ...

# %%
keep_columns1 = ['Entity','YEAR','records lost','ORGANISATION','METHOD OF LEAK','DATA SENSITIVITY']
csv_data_trunc1 = csv_data2[keep_columns1]
csv_data_trunc1
# Out:
# 0                                            Entity  \
# 0                                            Entity
# 1                                               NaN
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# ...

# %%
csv_data_trunc1.columns=['Entity','Year','Records Lost','Organization','Method of Leak','Data Sensitivity']
csv_data_trunc1
# Out:
#                                              Entity  \
# 0                                            Entity
# 1                                               NaN
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# ...

# %%
#Truncate unwanted columns
csv_columns1 = csv_data_trunc1.copy() 
csv_columns1 = csv_columns1.reindex(csv_columns1.index.drop(1))
csv_columns1
# Out:
#                                              Entity  Year  Records Lost  \
# 0                                            Entity  YEAR  records lost
# 2                                               AOL     0      92000000
# 3                         Automatic Data Processing     1        125000
# 4                                   Ameritrade Inc.     1        200000
# 5                                         Citigroup     1       3900000
# 6                       Cardsystems Solutions Inc.      1      40000000
# 7                                   Hewlett Packard     2        200000
# 8                        Countrywide Financial Corp     2       2600000
# 9                                              KDDI     2       4000000
# 10                       T-Mobile, Deutsche Telecom     2      17000000
# 11                                              AOL     2      20000000
# 12                           US Dept of Vet Affairs     2      26500000
# ...

# %%
#drop index column
csv_columns1 = csv_columns1.drop(csv_columns1.index[0])
csv_columns1
# Out:
#                                              Entity Year Records Lost  \
# 2                                               AOL    0     92000000
# 3                         Automatic Data Processing    1       125000
# 4                                   Ameritrade Inc.    1       200000
# 5                                         Citigroup    1      3900000
# 6                       Cardsystems Solutions Inc.     1     40000000
# 7                                   Hewlett Packard    2       200000
# 8                        Countrywide Financial Corp    2      2600000
# 9                                              KDDI    2      4000000
# 10                       T-Mobile, Deutsche Telecom    2     17000000
# 11                                              AOL    2     20000000
# 12                           US Dept of Vet Affairs    2     26500000
# 13                                    Texas Lottery    3        89000
# ...

# %%
csv_table1_Updated = csv_columns1.copy() #replace integer with Year
csv_table1_Updated['Year'].replace(to_replace='0',value='2004', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='1',value='2005', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='2',value='2006', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='3',value='2007', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='4',value='2008', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='5',value='2009', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='6',value='2010', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='7',value='2011', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='8',value='2012', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='9',value='2013', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='10',value='2014', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='11',value='2015', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='12',value='2016', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='13',value='2017', inplace=True)
csv_table1_Updated['Year'].replace(to_replace='14',value='2018', inplace=True)
csv_table1_Updated
# Out:
#                                              Entity  Year Records Lost  \
# 2                                               AOL  2004     92000000
# 3                         Automatic Data Processing  2005       125000
# 4                                   Ameritrade Inc.  2005       200000
# 5                                         Citigroup  2005      3900000
# 6                       Cardsystems Solutions Inc.   2005     40000000
# 7                                   Hewlett Packard  2006       200000
# 8                        Countrywide Financial Corp  2006      2600000
# 9                                              KDDI  2006      4000000
# 10                       T-Mobile, Deutsche Telecom  2006     17000000
# 11                                              AOL  2006     20000000
# 12                           US Dept of Vet Affairs  2006     26500000
# 13                                    Texas Lottery  2007        89000
# ...

# %%
#Update sensitivity values for integers
csv_table1_Updated['Data Sensitivity'].replace(to_replace='1',value='Online Contact Information', inplace=True)
csv_table1_Updated['Data Sensitivity'].replace(to_replace='20',value='Personal Details', inplace=True)
csv_table1_Updated['Data Sensitivity'].replace(to_replace='300',value='Credit Card Info', inplace=True)
csv_table1_Updated['Data Sensitivity'].replace(to_replace='4000',value='Email and Health Records', inplace=True)
csv_table1_Updated['Data Sensitivity'].replace(to_replace='50000',value='Full Bank Account Details', inplace=True)

csv_table1_Updated
# Out:
#                                              Entity  Year Records Lost  \
# 2                                               AOL  2004     92000000
# 3                         Automatic Data Processing  2005       125000
# 4                                   Ameritrade Inc.  2005       200000
# 5                                         Citigroup  2005      3900000
# 6                       Cardsystems Solutions Inc.   2005     40000000
# 7                                   Hewlett Packard  2006       200000
# 8                        Countrywide Financial Corp  2006      2600000
# 9                                              KDDI  2006      4000000
# 10                       T-Mobile, Deutsche Telecom  2006     17000000
# 11                                              AOL  2006     20000000
# 12                           US Dept of Vet Affairs  2006     26500000
# 13                                    Texas Lottery  2007        89000
# ...

# %%
#Change 2018 to latest (rectify the error)
csv_table1_Updated['Year'].replace(to_replace='2018',value='Latest', inplace=True)
csv_table1_Updated
# Out:
#                                              Entity    Year Records Lost  \
# 2                                               AOL    2004     92000000
# 3                         Automatic Data Processing    2005       125000
# 4                                   Ameritrade Inc.    2005       200000
# 5                                         Citigroup    2005      3900000
# 6                       Cardsystems Solutions Inc.     2005     40000000
# 7                                   Hewlett Packard    2006       200000
# 8                        Countrywide Financial Corp    2006      2600000
# 9                                              KDDI    2006      4000000
# 10                       T-Mobile, Deutsche Telecom    2006     17000000
# 11                                              AOL    2006     20000000
# 12                           US Dept of Vet Affairs    2006     26500000
# 13                                    Texas Lottery    2007        89000
# ...

# %%
#Drop na entries (rectify error 2)
csv_table1_Clean = csv_table1_Updated.copy()
csv_table1_Clean = csv_table1_Clean.dropna(axis="rows", how="any")
csv_table1_Clean
# Out:
#                                              Entity    Year Records Lost  \
# 2                                               AOL    2004     92000000
# 3                         Automatic Data Processing    2005       125000
# 4                                   Ameritrade Inc.    2005       200000
# 5                                         Citigroup    2005      3900000
# 6                       Cardsystems Solutions Inc.     2005     40000000
# 7                                   Hewlett Packard    2006       200000
# 8                        Countrywide Financial Corp    2006      2600000
# 9                                              KDDI    2006      4000000
# 10                       T-Mobile, Deutsche Telecom    2006     17000000
# 11                                              AOL    2006     20000000
# 12                           US Dept of Vet Affairs    2006     26500000
# 13                                    Texas Lottery    2007        89000
# ...

# %%
# Convert number of records lost in miilions
csv_table1_RecordsInM = csv_table1_Clean.copy()
csv_table1_RecordsInM['Records Lost (In Millions)'] = (csv_table1_RecordsInM['Records Lost'].astype(float)/1000000).round(3).astype(str)
csv_table1_RecordsInM
# Out:
#                                              Entity    Year Records Lost  \
# 2                                               AOL    2004     92000000
# 3                         Automatic Data Processing    2005       125000
# 4                                   Ameritrade Inc.    2005       200000
# 5                                         Citigroup    2005      3900000
# 6                       Cardsystems Solutions Inc.     2005     40000000
# 7                                   Hewlett Packard    2006       200000
# 8                        Countrywide Financial Corp    2006      2600000
# 9                                              KDDI    2006      4000000
# 10                       T-Mobile, Deutsche Telecom    2006     17000000
# 11                                              AOL    2006     20000000
# 12                           US Dept of Vet Affairs    2006     26500000
# 13                                    Texas Lottery    2007        89000
# ...

# %%
csv_table1_ColDel = csv_table1_RecordsInM.copy()
csv_table1_ColDel.drop('Records Lost',axis=1, inplace = True)
csv_table1_ColDel
# Out:
#                                              Entity    Year  \
# 2                                               AOL    2004
# 3                         Automatic Data Processing    2005
# 4                                   Ameritrade Inc.    2005
# 5                                         Citigroup    2005
# 6                       Cardsystems Solutions Inc.     2005
# 7                                   Hewlett Packard    2006
# 8                        Countrywide Financial Corp    2006
# 9                                              KDDI    2006
# 10                       T-Mobile, Deutsche Telecom    2006
# 11                                              AOL    2006
# 12                           US Dept of Vet Affairs    2006
# 13                                    Texas Lottery    2007
# 14     City and Hackney Teaching Primary Care Trust    2007
# 15                                          Gap Inc    2007
# 16                                     Compass Bank    2007
# ...

# %%
csv_table1_Clean_Copy = csv_table1_ColDel.copy()
csv_table1_Clean_Copy
# Out:
#                                              Entity    Year  \
# 2                                               AOL    2004
# 3                         Automatic Data Processing    2005
# 4                                   Ameritrade Inc.    2005
# 5                                         Citigroup    2005
# 6                       Cardsystems Solutions Inc.     2005
# 7                                   Hewlett Packard    2006
# 8                        Countrywide Financial Corp    2006
# 9                                              KDDI    2006
# 10                       T-Mobile, Deutsche Telecom    2006
# 11                                              AOL    2006
# 12                           US Dept of Vet Affairs    2006
# 13                                    Texas Lottery    2007
# 14     City and Hackney Teaching Primary Care Trust    2007
# 15                                          Gap Inc    2007
# 16                                     Compass Bank    2007
# ...

# %%
csv_table1_Clean_Copy['Organization'].replace(to_replace='government, military',value='Government', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='government, healthcare',value='Government', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='government',value='Government', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='military, healthcare',value='Military', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='military',value='Military', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='tech, retail',value='Tech', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='tech, web',value='Tech', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='tech',value='Tech', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='app',value='Tech', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='web, gaming',value='Web', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='web',value='Web', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='web, military',value='Web', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='web, tech',value='Web', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='telecoms',value='Telecoms', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='financial',value='Financial', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='academic',value='Academic', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='gaming',value='Gaming', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='energy',value='Energy', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='legal',value='Legal', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='media',value='Media', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='retail',value='Retail', inplace=True)
csv_table1_Clean_Copy['Organization'].replace(to_replace='healthcare',value='Healthcare', inplace=True)
csv_table1_Clean_Copy['Entity'].replace(to_replace='"Apple"',value='Apple', inplace=True)
csv_table1_Clean_Copy['Entity'].replace(to_replace='"Gmail"',value='GMail', inplace=True)
csv_table1_Clean_Copy['Entity'].replace(to_replace='Driving Standards Agency,',value='Driving Standards Agency', inplace=True)
csv_table1_Clean_Copy['Method of Leak'].replace(to_replace='accidentally published',value='Accidentally Published', inplace=True)
csv_table1_Clean_Copy['Method of Leak'].replace(to_replace='lost / stolen device',value='Lost / Stolen Device', inplace=True)
csv_table1_Clean_Copy['Method of Leak'].replace(to_replace='hacked',value='Hacked', inplace=True)
csv_table1_Clean_Copy['Method of Leak'].replace(to_replace='inside job',value='Inside Job', inplace=True)
csv_table1_Clean_Copy['Method of Leak'].replace(to_replace='poor security',value='Poor Security', inplace=True)
csv_table1_Clean_Copy
# Out:
#                                              Entity    Year Organization  \
# 2                                               AOL    2004          Web
# 3                         Automatic Data Processing    2005    Financial
# 4                                   Ameritrade Inc.    2005    Financial
# 5                                         Citigroup    2005    Financial
# 6                       Cardsystems Solutions Inc.     2005    Financial
# 7                                   Hewlett Packard    2006         Tech
# 8                        Countrywide Financial Corp    2006    Financial
# 9                                              KDDI    2006     Telecoms
# 10                       T-Mobile, Deutsche Telecom    2006     Telecoms
# 11                                              AOL    2006          Web
# 12                           US Dept of Vet Affairs    2006   Government
# 13                                    Texas Lottery    2007   Government
# ...

# %%
csv_table1_Clean_Copy.to_csv('Assignment2_Rucha.csv', index=False)
