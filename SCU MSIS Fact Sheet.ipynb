# %% [markdown]
# # Santa Clara University - Leavey School Of Business MSIS Fact Sheet

# %% [markdown]
# ## Claim : Santa Clara University is the best school in the Bay Area for prospective MS Information Systems students

# %%
pwd
# Out:
# 'C:\\Users\\kulka\\JupyterNotebooks'

# %% [markdown]
# #### Here is what the previous version of the fact sheet looks like -

# %%
from IPython.display import Image
Image("Lab session 5.png")

# %% [markdown]
# ### 1. Critique:
# #### 1.	The slide is not equally divided and the font sizes vary.
# #### 2.	The three components of the slide look disintegrated.
# #### 3.	Need some thought process and change of perspective with the sequence of the story
# #### 4.	Minimize the reading required for Course curriculum
# #### 5.	How is the course curriculum unique?
#
# ### 2. Roadmap for improvement:
# #### 1.	Make sure that the components in the slides are well-structured
# #### 2.	Integrate the components
# #### 3.	Present the story and thought process better
# #### 4.	Try to quantify the metrics
# #### 5.	Support the individual claims better

# %%
from IPython.display import Image
Image("LS-8.png")

# %% [markdown]
# ### 3. Why this visualization:
# #### It was clear in the first graph that the mid-career salaries in the state of California are higher than the average of the top 3 states with the highest salaries for Information Systems careers in the United States. The dataset that was used for the previous version did not seem correct when compared to the current dataset. Also, there was no way to find a correlation between these average salaries and the Top recruiters of SCU MSIS Alumni, especially for students who would be concerned with Entry-level jobs once they graduate. To integrate these facts, there was a need to have a common ground to find the average salary only for the Information Systems career at SCU for each of the top recruiters and compare them with the national average. In this way, the prospective students would be able to directly focus on base salaries for MSIS students at SCU, instead of the metrics of the state of California's average salary. A clear base salary comparison can now be made. Here is the national average salary compared with the overall average salaries of our recruiters-

# %% [markdown]
# #### Computer and Information Systems:
# #### National average salary USD 71,290
# #### SCU MSIS average salary USD 100,987
#
# ### 4. Conclusion:
# #### The metrics of average salaries and top employers of MSIS SCU alumni have been integrated. It is now clear to the prospective students that SCU MSIS students are not only recruited by the Fortune 100 employers but they also would get a head start in their careers in terms of starting salaries that are higher than 30% as compared to the national average.
